# %%
#Import important libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd
from random import randint
from time import sleep

# %%
# Get all the pages from poemhunter with Mary Oliver's poems:

pages = [] #list of all responses

#start with the first page, that has a slightly different url:
url ='https://www.best-poems.net/pablo_neruda/index.html'
print(url)
response = requests.get(url)
print("Status code: " + str(response.status_code))
pages.append(response)

# respectful nap:
wait_time = randint(1,4000)
print("I will sleep for " + str(wait_time/1000) + " second/s.")
sleep(wait_time/1000)



#In this for-loop the pages 1-5 are scraped and put into pages:
for i in range(1,5):
    page= str(i)
    url = 'https://www.best-poems.net/pablo_neruda/index.html?page=' + page
    print(url)
    
    response = requests.get(url)
    
    print("Status code: " + str(response.status_code))
    
    # store response into "pages" list
    pages.append(response)
    
    # respectful nap:
    wait_time = randint(1,4000)
    print("I will sleep for " + str(wait_time/1000) + " second/s.")
    sleep(wait_time/1000)
# Out:
# https://www.best-poems.net/pablo_neruda/index.html
# Status code: 200
# I will sleep for 0.178 second/s.
# https://www.best-poems.net/pablo_neruda/index.html?page=1
# Status code: 200
# I will sleep for 0.441 second/s.
# https://www.best-poems.net/pablo_neruda/index.html?page=2
# Status code: 200
# I will sleep for 0.444 second/s.
# https://www.best-poems.net/pablo_neruda/index.html?page=3
# Status code: 200
# I will sleep for 0.749 second/s.
# https://www.best-poems.net/pablo_neruda/index.html?page=4
# Status code: 200
# I will sleep for 0.148 second/s.

# %%
#Get the urls for the specific poems:

titles=[]
url_list= []

for i in range(len(pages)):
    # parse all pages
    parsed = BeautifulSoup(pages[i].content, "html.parser")
    
    # creating the title soup
    for j in range(1,31):
        title_soup = parsed.select('#content > ul > li:nth-child('+ str(j) +') > a')
    
    #And append every title to the titles list
        for item in title_soup:
            url_list.append(item.get("href"))
            titles.append(item.get_text())

# %%
len(url_list)
# Out:
# 131

# %%
titles
# Out:
# ['A Dog Has Died ',
#  'A Lemon',
#  'A Song Of Despair',
#  'Absence',
#  'Algunas Bestias',
#  'Always',
#  'And because Love battles',
#  'Bird',
#  'Brown And Agile Child',
#  'Carnal Apple, Woman Filled, Burning Moon',
#  'Castro Alves From Brazil',
#  "Cat's Dream",
#  'Clenched Soul',
#  'Come With Me, I Said, And No One Knew',
#  'Death Alone',
#  "Don't Go Far Off, Not Even For A Day",
#  'Drunk As Drunk',
#  'Enigma with Flower',
#  'Enigmas',
#  'Entrance Of The Rivers',
#  'Fable of the Mermaid and the Drunks',
#  'Finale',
#  'Fleas Interest Me So Much',
#  'From The Heights Of Maccho Picchu',
#  'Gautama Christ',
#  'Gentleman Alone',
#  'Here I Love You',
#  'I Crave Your Mouth, Your Voice, Your Hair',
#  'I Do Not Love You Except Because I Love You',
#  'I Explain A Few Things',
#  'I Like For You To Be Still',
#  'I like you calm, as if you were absent',
#  'I Remember You As You Were',
#  'In My Sky At Twilight',
#  'In the wave-strike over unquiet stones',
#  'In You The Earth',
#  "It's good to feel you are close to me",
#  'La Muerta',
#  'La Reina (and translation)',
#  'Leaning Into The Afternoons',
#  'Leave Me A Place Underground',
#  'Lone Gentleman',
#  'Lost In The Forest',
#  'Love',
#  'Love Sonnet XVII',
#  "Love, We're Going Home Now",
#  'Lovely One',
#  'Luminous mind, bright devil',
#  "LXXXIV From: 'Cien sonetos de amor'",
#  'Magellanic Penguin',
#  'March Days Return with their Covert Light',
#  'Morning (Love Sonnet XXVII)',
#  'Nothing But Death',
#  'Nothing But Death',
#  'Ode To a Chestnut on the Ground',
#  'Ode To a Large Tuna in the Market',
#  'Ode To a Lemon',
#  'Ode To A Naked Beauty',
#  'Ode To an Artichoke',
#  'Ode To Bird Watching',
#  'Ode To Broken Things',
#  'Ode to Clothes',
#  'Ode To Conger Chowder',
#  'Ode To Maize',
#  'Ode to My Socks',
#  'Ode To Sadness',
#  'Ode To Salt',
#  'Ode To The Artichoke',
#  'Ode To The Book',
#  'Ode To The Lemon',
#  'Ode To The Onion',
#  'Ode To Tomatoes',
#  'Ode To Wine',
#  'Perhaps Not To Be Is To Be Without Your Being',
#  'Poesia',
#  "Poet's Obligation",
#  'Poetry',
#  'Poor Creatures',
#  'Potter',
#  'Puedo Escribir',
#  'So that you will hear me',
#  'Some Beasts',
#  'Sonata',
#  'Soneto XVII',
#  'Sonnet IX: There where the waves shatter',
#  "Sonnet LXXIII: Maybe you'll remember",
#  'Sonnet LXXXI: Rest with your dream inside my dream',
#  'Sonnet VIII: If your eyes were not the color of the moon',
#  'Sonnet XCV:Who ever desired each other as we do',
#  'Sonnet XI',
#  'Sonnet XIII:The light that rises from your feet to your hair',
#  'Sonnet XLII: I Hunt For A Sign Of You',
#  'Sonnet XVII: I do not love you as if you were brine-rose, topaz',
#  'Sonnet XXVII: Naked You Are As Simple as one of your Hands',
#  'Sonnet XXXIV',
#  'Tell Me, Is The Rose Naked?',
#  'The Dead Woman',
#  'The Dictators',
#  'The Eighth of September',
#  'The Fear',
#  'The Fickle One',
#  'The House of Odes',
#  'The Insect',
#  'The Light Wraps You',
#  'The Men',
#  'The Night In Isla Negra',
#  'The Old Women Of The Ocean',
#  'The People',
#  'The Portrait In The Rock',
#  'The Queen',
#  'The Question',
#  'The Tree Is Here, Still, In Pure Stone',
#  'The United Fruit Co.',
#  'The Weary One',
#  'The White Mans Burden',
#  'The Wide Ocean',
#  'Tie Your Heart At Night To Mine, Love,',
#  'Tonight I Can Write',
#  'Tower Of Light',
#  'Triangles',
#  'Walking Around',
#  'Waltz',
#  'Water',
#  'We Are Many',
#  'What Spain Was Like',
#  'XVII (I do not love you...)',
#  'XVII (Thinking, Tangling Shadows...)',
#  'XXXIV (You are the daughter of the sea)',
#  'Your Feet',
#  'Your Hands',
#  'Your Laughter']

# %%
# Now get the poems itself:

poem_soup = []

for url in url_list:
    page = 'https://www.best-poems.net'+str(url) #Create url by means of the url_list
    print(page)
    
    response = requests.get(page)               # Get the soup of the webpage
    print("Status code: " + str(response.status_code))
    
    poem_soup.append(response)                  # Append to poem_soup; later I will get the poems from this soup
    
    # respectful nap:
    wait_time = randint(1,4000)
    print("I will sleep for " + str(wait_time/1000) + " second/s.")
    sleep(wait_time/1000)
# Out:
# https://www.best-poems.net/pablo_neruda/a_dog_has_died_1.html
# Status code: 200
# I will sleep for 2.077 second/s.
# https://www.best-poems.net/pablo-neruda/a-lemon.html
# Status code: 200
# I will sleep for 0.013 second/s.
# https://www.best-poems.net/pablo_neruda/a_song_of_despair.html
# Status code: 200
# I will sleep for 3.941 second/s.
# https://www.best-poems.net/poem/absence-by-absence.html
# Status code: 200
# I will sleep for 2.912 second/s.
# https://www.best-poems.net/poem/algunas-bestias-by-pablo-neruda.html
# Status code: 200
# I will sleep for 1.544 second/s.
# https://www.best-poems.net/pablo_neruda/always.html
# Status code: 200
# I will sleep for 1.743 second/s.
# https://www.best-poems.net/love_poems/and_because_love_battles.html
# Status code: 200
# I will sleep for 3.083 second/s.
# https://www.best-poems.net/poem/bird-by-pablo-neruda.html
# Status code: 200
# I will sleep for 1.122 second/s.
# https://www.best-poems.net/poem/brown-and-agile-child-by-pablo-neruda.html
# Status code: 200
# I will sleep for 3.183 second/s.
# https://www.best-poems.net/pablo-neruda/carnal-apple-woman-filled-burning-moon.html
# Status code: 200
# I will sleep for 3.793 second/s.
# https://www.best-poems.net/pablo-neruda/castro-alves-from-brazil.html
# Status code: 200
# I will sleep for 0.918 second/s.
# https://www.best-poems.net/pablo_neruda/cats_dream.html
# Status code: 200
# I will sleep for 1.092 second/s.
# https://www.best-poems.net/pablo_neruda/clenched_soul_1.html
# Status code: 200
# I will sleep for 0.909 second/s.
# https://www.best-poems.net/pablo_neruda/come_with_me_i_said_and_no_one_knew_vii.html
# Status code: 200
# I will sleep for 3.836 second/s.
# https://www.best-poems.net/funerals/death_alone.html
# Status code: 200
# I will sleep for 3.845 second/s.
# https://www.best-poems.net/pablo_neruda/don039t_go_far_off_not_even_for_a_day.html
# Status code: 200
# I will sleep for 2.505 second/s.
# https://www.best-poems.net/pablo_neruda/drunk_as_drunk.html
# Status code: 200
# I will sleep for 3.663 second/s.
# https://www.best-poems.net/pablo-neruda/enigma-with-flower.html
# Status code: 200
# I will sleep for 3.5 second/s.
# https://www.best-poems.net/pablo_neruda/enigmas_1.html
# Status code: 200
# I will sleep for 2.771 second/s.
# https://www.best-poems.net/pablo-neruda/entrance-of-the-rivers.html
# Status code: 200
# I will sleep for 1.542 second/s.
# https://www.best-poems.net/pablo-neruda/fable-of-the-mermaid-and-the-drunks.html
# Status code: 200
# I will sleep for 2.776 second/s.
# https://www.best-poems.net/poem/finale-by-pablo-neruda.html
# Status code: 200
# I will sleep for 0.931 second/s.
# https://www.best-poems.net/poem/fleas-interest-me-so-much-by-pablo-neruda.html
# Status code: 200
# I will sleep for 3.694 second/s.
# https://www.best-poems.net/pablo-neruda/from-the-heights-of-maccho-picchu.html
# Status code: 200
# I will sleep for 2.03 second/s.
# https://www.best-poems.net/poem/gautama-christ-by-christ.html
# Status code: 200
# I will sleep for 0.84 second/s.
# https://www.best-poems.net/pablo_neruda/gentleman_alone_1.html
# Status code: 200
# I will sleep for 3.161 second/s.
# https://www.best-poems.net/poem/here-i-love-you-by-pablo-neruda.html
# Status code: 200
# I will sleep for 2.722 second/s.
# https://www.best-poems.net/lonely_poems/i_crave_your_mouth_your_voice_your_hair.html
# Status code: 200
# I will sleep for 3.241 second/s.
# https://www.best-poems.net/pablo_neruda/i_do_not_love_you_except_because_i_love_you.html
# Status code: 200
# I will sleep for 3.661 second/s.
# https://www.best-poems.net/pablo-neruda/i-explain-a-few-things.html
# Status code: 200
# I will sleep for 3.313 second/s.
# https://www.best-poems.net/pablo_neruda/i_like_for_you_to_be_still.html
# Status code: 200
# I will sleep for 2.968 second/s.
# https://www.best-poems.net/pablo-neruda/i-like-you-calm-as-if-you-were-absent.html
# Status code: 200
# I will sleep for 3.202 second/s.
# https://www.best-poems.net/pablo-neruda/i-remember-you-as-you-were.html
# Status code: 200
# I will sleep for 0.78 second/s.
# https://www.best-poems.net/pablo-neruda/in-my-sky-at-twilight.html
# Status code: 200
# I will sleep for 3.995 second/s.
# https://www.best-poems.net/pablo-neruda/in-the-wave-strike-over-unquiet-stones.html
# Status code: 200
# I will sleep for 2.818 second/s.
# https://www.best-poems.net/pablo-neruda/in-you-the-earth.html
# Status code: 200
# I will sleep for 0.351 second/s.
# https://www.best-poems.net/pablo-neruda/its-good-to-feel-you-are-close-to-me.html
# Status code: 200
# I will sleep for 3.589 second/s.
# https://www.best-poems.net/poem/la-muerta-by-pablo-neruda.html
# Status code: 200
# I will sleep for 0.922 second/s.
# https://www.best-poems.net/poem/la-reina-and-translation-by-pablo-neruda.html
# Status code: 200
# I will sleep for 0.24 second/s.
# https://www.best-poems.net/pablo_neruda/leaning_into_the_afternoons_1.html
# Status code: 200
# I will sleep for 1.226 second/s.
# https://www.best-poems.net/pablo-neruda/leave-me-a-place-underground.html
# Status code: 200
# I will sleep for 3.405 second/s.
# https://www.best-poems.net/poem/lone-gentleman-by-pablo-neruda.html
# Status code: 200
# I will sleep for 1.418 second/s.
# https://www.best-poems.net/pablo-neruda/lost-in-the-forest.html
# Status code: 200
# I will sleep for 2.596 second/s.
# https://www.best-poems.net/pablo_neruda/love.html
# Status code: 200
# I will sleep for 3.885 second/s.
# https://www.best-poems.net/pablo_neruda/love_sonnet_xvii.html
# Status code: 200
# I will sleep for 0.681 second/s.
# https://www.best-poems.net/pablo-neruda/love-were-going-home-now.html
# Status code: 200
# I will sleep for 1.335 second/s.
# https://www.best-poems.net/poem/lovely-one-by-pablo-neruda.html
# Status code: 200
# I will sleep for 2.529 second/s.
# https://www.best-poems.net/poem/luminous-mind-bright-devil-by-pablo-neruda.html
# Status code: 200
# I will sleep for 0.189 second/s.
# https://www.best-poems.net/pablo-neruda/lxxxiv-from-cien-sonetos-de-amor.html
# Status code: 200
# I will sleep for 2.616 second/s.
# https://www.best-poems.net/pablo_neruda/magellanic_penguin_1.html
# Status code: 200
# I will sleep for 3.499 second/s.
# https://www.best-poems.net/pablo-neruda/march-days-return-with-their-covert-light.html
# Status code: 200
# I will sleep for 0.772 second/s.
# https://www.best-poems.net/pablo_neruda/morning_love_sonnet_xxvii.html
# Status code: 200
# I will sleep for 1.598 second/s.
# https://www.best-poems.net/pablo_neruda/nothing_but_death_1.html
# Status code: 200
# I will sleep for 1.037 second/s.
# https://www.best-poems.net/pablo-neruda/nothing-but-death.html
# Status code: 200
# I will sleep for 0.672 second/s.
# https://www.best-poems.net/pablo_neruda/ode_to_a_chestnut_on_the_ground_1.html
# Status code: 200
# I will sleep for 2.557 second/s.
# https://www.best-poems.net/pablo_neruda/ode_to_a_large_tuna_in_the_market_1.html
# Status code: 200
# I will sleep for 3.821 second/s.
# https://www.best-poems.net/pablo_neruda/ode_to_a_lemon_1.html
# Status code: 200
# I will sleep for 0.938 second/s.
# https://www.best-poems.net/pablo-neruda/ode-to-a-naked-beauty.html
# Status code: 200
# I will sleep for 3.904 second/s.
# https://www.best-poems.net/pablo_neruda/ode_to_an_artichoke_1.html
# Status code: 200
# I will sleep for 0.442 second/s.
# https://www.best-poems.net/pablo-neruda/ode-to-bird-watching.html
# Status code: 200
# I will sleep for 0.412 second/s.
# https://www.best-poems.net/pablo-neruda/ode-broken-things.html
# Status code: 200
# I will sleep for 2.4 second/s.
# https://www.best-poems.net/pablo-neruda/ode-clothes.html
# Status code: 200
# I will sleep for 2.89 second/s.
# https://www.best-poems.net/pablo_neruda/ode_to_conger_chowder.html
# Status code: 200
# I will sleep for 0.897 second/s.
# https://www.best-poems.net/pablo_neruda/ode_to_maize_1.html
# Status code: 200
# I will sleep for 1.965 second/s.
# https://www.best-poems.net/pablo-neruda/ode-to-my-socks.html
# Status code: 200
# I will sleep for 3.898 second/s.
# https://www.best-poems.net/pablo-neruda/ode-to-sadness.html
# Status code: 200
# I will sleep for 2.187 second/s.
# https://www.best-poems.net/pablo_neruda/ode_to_salt.html
# Status code: 200
# I will sleep for 0.353 second/s.
# https://www.best-poems.net/pablo_neruda/ode_to_the_artichoke.html
# Status code: 200
# I will sleep for 1.333 second/s.
# https://www.best-poems.net/pablo-neruda/ode-book.html
# Status code: 200
# I will sleep for 0.754 second/s.
# https://www.best-poems.net/pablo_neruda/ode_to_the_lemon.html
# Status code: 200
# I will sleep for 3.141 second/s.
# https://www.best-poems.net/pablo_neruda/ode_to_the_onion_1.html
# Status code: 200
# I will sleep for 0.912 second/s.
# https://www.best-poems.net/pablo_neruda/ode_to_tomatoes.html
# Status code: 200
# I will sleep for 3.876 second/s.
# https://www.best-poems.net/pablo_neruda/ode_to_wine.html
# Status code: 200
# I will sleep for 2.801 second/s.
# https://www.best-poems.net/pablo-neruda/039perhaps-not-be-be-without-your-being039.html
# Status code: 200
# I will sleep for 2.583 second/s.
# https://www.best-poems.net/pablo-neruda/poesia.html
# Status code: 200
# I will sleep for 1.826 second/s.
# https://www.best-poems.net/pablo-neruda/poet039s-obligation.html
# Status code: 200
# I will sleep for 1.738 second/s.
# https://www.best-poems.net/pablo-neruda/poetry.html
# Status code: 200
# I will sleep for 1.129 second/s.
# https://www.best-poems.net/pablo-neruda/poor-creatures.html
# Status code: 200
# I will sleep for 2.744 second/s.
# https://www.best-poems.net/pablo-neruda/potter.html
# Status code: 200
# I will sleep for 3.618 second/s.
# https://www.best-poems.net/pablo_neruda/puedo_escribir.html
# Status code: 200
# I will sleep for 1.722 second/s.
# https://www.best-poems.net/pablo-neruda/so-you-will-hear-me.html
# Status code: 200
# I will sleep for 3.485 second/s.
# https://www.best-poems.net/pablo-neruda/some-beasts.html
# Status code: 200
# I will sleep for 2.085 second/s.
# https://www.best-poems.net/pablo-neruda/sonata.html
# Status code: 200
# I will sleep for 0.915 second/s.
# https://www.best-poems.net/pablo-neruda/soneto-xvii.html
# Status code: 200
# I will sleep for 1.907 second/s.
# https://www.best-poems.net/pablo-neruda/sonnet-ix-there-where-waves-shatter.html
# Status code: 200
# I will sleep for 1.272 second/s.
# https://www.best-poems.net/pablo-neruda/sonnet-lxxiii-maybe-youll-remember.html
# Status code: 200
# I will sleep for 0.382 second/s.
# https://www.best-poems.net/pablo-neruda/sonnet-lxxxi-rest-with-your-dream-inside-my-dream.html
# Status code: 200
# I will sleep for 0.463 second/s.
# https://www.best-poems.net/pablo-neruda/sonnet-viii-if-your-eyes-were-not-color-moon.html
# Status code: 200
# I will sleep for 1.044 second/s.
# https://www.best-poems.net/pablo-neruda/sonnet-xcvwho-ever-desired-each-other-we-do.html
# Status code: 200
# I will sleep for 3.193 second/s.
# https://www.best-poems.net/pablo-neruda/sonnet-xi.html
# Status code: 200
# I will sleep for 3.146 second/s.
# https://www.best-poems.net/pablo-neruda/sonnet-xiiithe-light-that-rises-from-your-feet-to-your-hair.html
# Status code: 200
# I will sleep for 0.019 second/s.
# https://www.best-poems.net/pablo-neruda/sonnet-xlii-i-hunt-for-a-sign-of-you.html
# Status code: 200
# I will sleep for 1.211 second/s.
# https://www.best-poems.net/pablo-neruda/sonnet-xvii-i-do-not-love-you-as-if-you-were-brine-rose-topaz.html
# Status code: 200
# I will sleep for 2.894 second/s.
# https://www.best-poems.net/pablo-neruda/sonnet-xxvii-naked-you-are-as-simple-as-one-of-your-hands.html
# Status code: 200
# I will sleep for 0.304 second/s.
# https://www.best-poems.net/poem/sonnet-xxxiv-by-pablo-neruda.html
# Status code: 200
# I will sleep for 1.242 second/s.
# https://www.best-poems.net/pablo-neruda/tell-me-is-the-rose-naked.html
# Status code: 200
# I will sleep for 3.25 second/s.
# https://www.best-poems.net/about_loss/the_dead_woman.html
# Status code: 200
# I will sleep for 3.867 second/s.
# https://www.best-poems.net/pablo_neruda/the_dictators_1.html
# Status code: 200
# I will sleep for 1.538 second/s.
# https://www.best-poems.net/pablo-neruda/the-eighth-of-september.html
# Status code: 200
# I will sleep for 0.897 second/s.
# https://www.best-poems.net/pablo-neruda/the-fear.html
# Status code: 200
# I will sleep for 1.32 second/s.
# https://www.best-poems.net/pablo-neruda/the-fickle-one.html
# Status code: 200
# I will sleep for 2.449 second/s.
# https://www.best-poems.net/pablo-neruda/the-house-of-odes.html
# Status code: 200
# I will sleep for 2.861 second/s.
# https://www.best-poems.net/pablo-neruda/the-insect.html
# Status code: 200
# I will sleep for 0.868 second/s.
# https://www.best-poems.net/pablo_neruda/the_light_wraps_you_1.html
# Status code: 200
# I will sleep for 3.547 second/s.
# https://www.best-poems.net/pablo-neruda/the-men.html
# Status code: 200
# I will sleep for 1.173 second/s.
# https://www.best-poems.net/pablo-neruda/the-night-in-isla-negra.html
# Status code: 200
# I will sleep for 0.636 second/s.
# https://www.best-poems.net/pablo-neruda/the-old-women-of-the-ocean.html
# Status code: 200
# I will sleep for 3.313 second/s.
# https://www.best-poems.net/pablo-neruda/the-people.html
# Status code: 200
# I will sleep for 1.424 second/s.
# https://www.best-poems.net/pablo-neruda/the-portrait-in-the-rock.html
# Status code: 200
# I will sleep for 3.713 second/s.
# https://www.best-poems.net/pablo-neruda/the-queen.html
# Status code: 200
# I will sleep for 3.279 second/s.
# https://www.best-poems.net/pablo-neruda/the-question.html
# Status code: 200
# I will sleep for 1.13 second/s.
# https://www.best-poems.net/pablo-neruda/the-tree-is-here-still-in-pure-stone.html
# Status code: 200
# I will sleep for 0.109 second/s.
# https://www.best-poems.net/pablo-neruda/the-united-fruit-co.html
# Status code: 200
# I will sleep for 1.051 second/s.
# https://www.best-poems.net/pablo-neruda/the-weary-one.html
# Status code: 200
# I will sleep for 0.079 second/s.
# https://www.best-poems.net/pablo_neruda/the_white_mans_burden_1.html
# Status code: 200
# I will sleep for 0.929 second/s.
# https://www.best-poems.net/pablo-neruda/the-wide-ocean.html
# Status code: 200
# I will sleep for 1.163 second/s.
# https://www.best-poems.net/pablo-neruda/tie-your-heart-at-night-to-mine-love.html
# Status code: 200
# I will sleep for 0.717 second/s.
# https://www.best-poems.net/pablo_neruda/tonight_i_can_write.html
# Status code: 200
# I will sleep for 2.854 second/s.
# https://www.best-poems.net/pablo_neruda/tower_of_light_1.html
# Status code: 200
# I will sleep for 0.746 second/s.
# https://www.best-poems.net/poem/triangles-by-pablo-neruda.html
# Status code: 200
# I will sleep for 1.431 second/s.
# https://www.best-poems.net/pablo_neruda/walking_around.html
# Status code: 200
# I will sleep for 2.378 second/s.
# https://www.best-poems.net/poem/waltz-by-pablo-neruda.html
# Status code: 200
# I will sleep for 1.167 second/s.
# https://www.best-poems.net/poem/water-by-pablo-neruda.html
# Status code: 200
# I will sleep for 3.027 second/s.
# https://www.best-poems.net/poem/we-are-many-by-pablo-neruda.html
# Status code: 200
# I will sleep for 2.031 second/s.
# https://www.best-poems.net/pablo-neruda/what-spain-was-like.html
# Status code: 200
# I will sleep for 0.978 second/s.
# https://www.best-poems.net/pablo_neruda/xvii_i_do_not_love_you.html
# Status code: 200
# I will sleep for 3.889 second/s.
# https://www.best-poems.net/pablo_neruda/xvii_thinking_tangling_shadows.html
# Status code: 200
# I will sleep for 2.862 second/s.
# https://www.best-poems.net/pablo_neruda/xxxiv_you_are_the_daughter_of_the_sea_1.html
# Status code: 200
# I will sleep for 1.428 second/s.
# https://www.best-poems.net/pablo_neruda/your_feet_1.html
# Status code: 200
# I will sleep for 2.192 second/s.
# https://www.best-poems.net/poem/your-hands-by-hand.html
# Status code: 200
# I will sleep for 2.002 second/s.
# https://www.best-poems.net/poem/your-laughter-by-laugh.html
# Status code: 200
# I will sleep for 0.54 second/s.

# %%
poems_text = []

for i in range(len(poem_soup)):
    # parse all pages
    parsed = BeautifulSoup(poem_soup[i].content, "html.parser")
    
    # creating the poem soup
    #beatiful_poem_soup = parsed.select('#content')
    text = parsed.select('#content')[0].get_text()
    poems_text.append(text)

# %%
#Put this all together in a dataframe and save it in a csv-file:
df = pd.DataFrame({'title':titles, 'text':poems_text})
df
# Out:
#                                        title  \
# 0                            A Dog Has Died
# 1                                    A Lemon
# 2                          A Song Of Despair
# 3                                    Absence
# 4                            Algunas Bestias
# ..                                       ...
# 126     XVII (Thinking, Tangling Shadows...)
# 127  XXXIV (You are the daughter of the sea)
# 128                                Your Feet
# 129                               Your Hands
# 130                            Your Laughter
#
#                                                   text
# 0    \nMy dog has died.\nI buried him in the garden...
# 1    \n\nOut of lemon flowers\nloosed\non the moonl...
# 2    \nThe memory of you emerges from the night aro...
# 3    \n\nI have scarcely left you\nWhen you go in m...
# 4    \n\nEra el crepúsculo de la iguana.\nDesde la ...
# ..                                                 ...
# 126  \nThinking, tangling shadows in the deep solit...
# 127  \nYou are the daughter of the sea, oregano's f...
# 128  \nWhen I cannot look at your face\nI look at y...
# 129  \n\nWhen your hands leap\ntowards mine, love,\...
# 130  \n\nTake bread away from me, if you wish,\ntak...
#
# [131 rows x 2 columns]

# %%
df.to_csv('pablo_neruda.csv', index=False)
